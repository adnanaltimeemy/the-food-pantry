# %%
import pandas as pd

# Create DataFrame
data = [
    {
        "business": "Gultekin Bakery",
        "region": "North West",
        "category": "Bakery",
        "menu_items": ["Baklava", "Pastries", "Bread"],
        "target_demographic": "Local families, dessert lovers",
        "avg_price": 3.5,
        "weekly_customers": 400,
        "weekly_revenue": 400 * 3.5,
        "yearly_revenue": (400 * 3.5) * 52,
        "notes": "Specialises in traditional baklava and sweet pastries."
    },
    {
        "business": "Syria Sweets ltd",
        "region": "North West",
        "category": "Candy/Sweets",
        "menu_items": ["Baklava", "Sweets", "Confectionery"],
        "target_demographic": "Young people, families",
        "avg_price": 4.0,
        "weekly_customers": 300,
        "weekly_revenue": 300 * 4.0,
        "yearly_revenue": (300 * 4.0) * 52,
        "notes": "Dessert seller with sweets and baklava variations."
    },
    {
        "business": "Pistachio",
        "region": "North West",
        "category": "Sweet House",
        "menu_items": ["Baklava", "Turkish sweets"],
        "target_demographic": "Middle Eastern food fans, tourists",
        "avg_price": 4.5,
        "weekly_customers": 250,
        "weekly_revenue": 250 * 4.5,
        "yearly_revenue": (250 * 4.5) * 52,
        "notes": "Higher prices, niche sweet house items."
    },
    {
        "business": "The Baklava Company",
        "region": "North West",
        "category": "Bakery",
        "menu_items": ["Baklava platters", "Kunefe", "Baklava ice cream"],
        "target_demographic": "Coffee shop crowd, tourists, dessert lovers",
        "avg_price": 5.5,
        "weekly_customers": 600,
        "weekly_revenue": 600 * 5.5,
        "yearly_revenue": (600 * 5.5) * 52,
        "notes": "Well-rated specialty baklava business with drink options."  # from JustEat menu list example :contentReference[oaicite:0]{index=0}
    },
    {
        "business": "Baklavaty",
        "region": "South West",
        "category": "Food Producer",
        "menu_items": ["Baklava", "Middle Eastern desserts"],
        "target_demographic": "Online buyers, dessert markets",
        "avg_price": 6.0,
        "weekly_customers": 200,
        "weekly_revenue": 200 * 6.0,
        "yearly_revenue": (200 * 6.0) * 52,
        "notes": "Higher price point, focuses on premium dessert production."
    },
    {
        "business": "Bristanbul",
        "region": "South West",
        "category": "Bakery",
        "menu_items": ["Baklava slices", "Bread", "Savouries"],
        "target_demographic": "Local customers, families",
        "avg_price": 4.0,
        "weekly_customers": 450,
        "weekly_revenue": 450 * 4.0,
        "yearly_revenue": (450 * 4.0) * 52,
        "notes": "Popular local bakery with a broad menu."
    },
    {
        "business": "Sotiris Greek Bakery",
        "region": "South West",
        "category": "Bakery",
        "menu_items": ["Baklava", "Greek pastries", "Coffee"],
        "target_demographic": "Ethnic food lovers, tourists",
        "avg_price": 4.2,
        "weekly_customers": 380,
        "weekly_revenue": 380 * 4.2,
        "yearly_revenue": (380 * 4.2) * 52,
        "notes": "High reviews for Greek desserts."
    },
    {
        "business": "D&D Bakery&Sweets",
        "region": "South West",
        "category": "Bakery",
        "menu_items": ["Baklava", "Cupcakes", "Bread"],
        "target_demographic": "General public, families",
        "avg_price": 3.8,
        "weekly_customers": 320,
        "weekly_revenue": 320 * 3.8,
        "yearly_revenue": (320 * 3.8) * 52,
        "notes": "Dessert hybrid bakery with competitive pricing."
    }
]

df = pd.DataFrame(data)

# Show dataset
df
# Out:
#                business      region       category  \
# 0       Gultekin Bakery  North West         Bakery
# 1      Syria Sweets ltd  North West   Candy/Sweets
# 2             Pistachio  North West    Sweet House
# 3   The Baklava Company  North West         Bakery
# 4             Baklavaty  South West  Food Producer
# 5            Bristanbul  South West         Bakery
# 6  Sotiris Greek Bakery  South West         Bakery
# 7     D&D Bakery&Sweets  South West         Bakery
#
#                                       menu_items  \
# 0                     [Baklava, Pastries, Bread]
# 1               [Baklava, Sweets, Confectionery]
# 2                      [Baklava, Turkish sweets]
# 3  [Baklava platters, Kunefe, Baklava ice cream]
# 4             [Baklava, Middle Eastern desserts]
# 5             [Baklava slices, Bread, Savouries]
# 6              [Baklava, Greek pastries, Coffee]
# 7                     [Baklava, Cupcakes, Bread]
#
# ...
